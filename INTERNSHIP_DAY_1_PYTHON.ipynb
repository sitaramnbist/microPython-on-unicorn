# %% [markdown]
# <a href="https://colab.research.google.com/github/sitaramnbist/microPython-on-unicorn/blob/main/INTERNSHIP_DAY_1_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# list

# %%
a=["A","B","C","D"]
a.append("E")
a.remove("B")
print(a[1])
# Out:
# C

# %%
b=["cat","dog","fly"]
b.append("car")
b.remove("cat")
print(b[0])
# Out:
# dog

# %% [markdown]
# tuple

# %%
colors=("red","blue","green","blue")
print(colors[1])
print(len(colors))
print(colors.count("blue"))
# Out:
# blue
# 4
# 2

# %% [markdown]
# type conversion

# %%
a=[1,2,3]
b=tuple(a)
print(b)

c=("cat","ball","apple")
d=list(c)
print(d)
# Out:
# (1, 2, 3)
# ['cat', 'ball', 'apple']

# %% [markdown]
# set

# %%
b={1,2,2,3,3,4,5,6,6,}
print(b)
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# mixed data types

# %%
s3={1,"apple",3.5,(2,4)}
print(s3)
# Out:
# {1, (2, 4), 3.5, 'apple'}

# %% [markdown]
# dictionary

# %%
student={"name":"Sitaram","age":20,"course":"EL"}
print(student["name"])
# Out:
# Sitaram

# %% [markdown]
# for condition

# %%
fruits={"apple","banana","cherry"}
for i in fruits:
  print(i)
# Out:
# apple
# cherry
# banana

# %% [markdown]
# while condition

# %%
i=1
while i<=5:
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
while True:
    print("this will be go on forever!")
# Out:
# Streaming output truncated to the last 5000 lines.
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# this will be go on forever!
# ...

# %%
i=1
while i<=10:
  print("1 x",i,"=",i*1)
  i+=1

# %%
num=int(input("enter a number:"))
for i in range(1,11):
  print(f"{num}x{i}={num*i}")

# %% [markdown]
# condition statement

# %%
y=10
if y>5:
  print("y is greater than 5")
else:
  print("y is 5 or less")

# %% [markdown]
# if....elif statement

# %%
mark=int(input("enter a number:"))
if mark>=90:
  print("a")
elif mark>=80:
  print("b")
elif mark>=70:
  print("c")
elif mark>=60:
  print("d")
else:
  print("f")

# %% [markdown]
# nested if

# %%
x=15
if x>1:
  if x % 2==0:
    print("x is largeer than 10 and even")
  else:
    print("x is larger than 10 and odd")

# %%
number=1
if i>=0:
  print("number is positive")
else:
  print("number is negitive")

# %% [markdown]
# function

# %%
def greet():
  print("hello,Welcome to python!")
greet()

# %%
def greet(name="a"):
  print("hello",name)
greet("Raja")

# %%
def add(a,b):
  c=a+b
  print(c)

# %%
def print_table(n):
  for i in range(1,11):
    print(f"{n}x{i}={n*i}")

# %%
def max_of_three(a,b,c):
  if a>=b and a>=c:
    return a
  elif b>=a and b>=c:
    return b
  else:
    return c

# %%
s=input("enter a string")
for i in s:
  if s.count(i)==1:
    print("first non repeating character:",i)
    break

# %%
for i in range (1,6):
  for j in range(i):
    print(i,end="")
  print()

# %%
qn 1

# %%
def count_vowels(text):
  count=0
  for letter in text:
    if letter in "aeiou":
      count +=1
  return count

# %% [markdown]
# qn 2

# %%
def if_prime(num):
  if num <2:
    return False
  for i in range (2,num):
    if num %i==0:
      return False
  return True

# %% [markdown]
# qn 3

# %%
def count_character(test,character):
  count=0
  for letter in next:
    if letter==character:
      count +=1
  return count

# %% [markdown]
# qn4

# %%
def count_odd_digits(num):
  count=0
  for digit in str(num):
    if int(digit)%2!=0:
      count+=1
  return count

# %% [markdown]
# qn 5

# %%
def remove_spaces(text):
  resut=""
  for letter in text:
    if letter!="":
      result += letter
  return result

# %% [markdown]
# qn 6

# %%
def smallest(a,b,c):
  if a<=b and a<=c:
    return a
  elif b<=c:
    return b
  else:
    return c

# %% [markdown]
# OOPS

# %%
class student:
  def _init_(self,attrubutes):
    self.attributes =attributes

# %%
obj=ClassName(value)

# %%
class student:
  def __init__(self, name, age):
    self.name=name
    self.age=age
  def display (self):
    print (self.name)
    print(self.age)

s1=student("ram",20)
s1.display()

# %%
''
